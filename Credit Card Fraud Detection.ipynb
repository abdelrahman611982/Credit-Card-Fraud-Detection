# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt   
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\osman\Desktop\Credit-Card-Fraud-Detection\creditcard.csv")
# Show all columns
pd.options.display.max_columns = None
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isna().sum().sum()
df.duplicated().sum().sum()
print(f"Number of duplicated rows: {df.duplicated().sum()}")
print(f"Number of null values: {df.isna().sum().sum()}")
# Out:
# Number of duplicated rows: 1081
# Number of null values: 0

# %%
df.drop_duplicates(inplace=True)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))


# First boxplot: 'Amount' by 'Class'
df.boxplot(column='Amount', by='Class', ax=ax[0])
ax[0].set_title('Boxplot of Amount by Class')
ax[0].set_xlabel('Class')
ax[0].set_ylabel('Amount')

# Second boxplot: 'Amount' without grouping by 'Class'
df.boxplot(column="Amount", ax=ax[1])
ax[1].set_title('Boxplot of Amount without grouping')
ax[1].set_xlabel('Class')
ax[1].set_ylabel('Amount')
 
plt.suptitle('Boxplots of Amount and V1 by Class')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Amount'], bins=50, kde=True, log_scale=True)
plt.title('Distribution of Amount') 
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
df_fraud = df[df['Class'] == 1]
df_normal = df[df['Class'] == 0].sample(5000, random_state=42)

pd.plotting.scatter_matrix(df_fraud.iloc[:, :6], figsize=(10,10), diagonal='kde')
plt.suptitle("Fraud Only")
plt.show()

# %%
# Keep only numeric columns
df_numeric = df.select_dtypes(include=[np.number])

# Keep columns with more than 1 unique value
df_numeric = df_numeric.loc[:, df_numeric.nunique() > 1]

# Reduce number of columns if too many (max 10)
if df_numeric.shape[1] > 10:
    df_numeric = df_numeric.iloc[:, :10]

# Plot scatter matrix
ax = pd.plotting.scatter_matrix(
    df_numeric,
    alpha=0.75,
    figsize=(12, 12),
    diagonal='kde'
)

# Calculate correlations
corrs = df_numeric.corr().values

# Add correlation text to upper triangle
for i, j in zip(*np.triu_indices_from(corrs, k=1)):
    ax[i, j].annotate(
        f'Corr = {corrs[i, j]:.3f}',
        (0.8, 0.2),
        xycoords='axes fraction',
        ha='center',
        va='center',
        size=9
    )

plt.suptitle('Scatter and Density Plot', y=1.02)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

class_counts = df['Class'].value_counts().sort_index()
labels = ['Normal', 'Fraud']

# Bar chart
ax[1].bar(labels, class_counts)
ax[1].set_title('Class Distribution (Count)')
ax[1].set_ylabel('Number of Transactions')

# Pie chart
ax[0].pie(class_counts, labels=labels, autopct='%1.2f%%', startangle=45, shadow=True)
ax[0].set_title('Class Distribution (Percentage)')

plt.tight_layout()
plt.show()

# %%
target = 'Class'

corr_with_target = (df.corr()[target].sort_values(ascending=False))

plt.figure(figsize=(10, 15))
sns.heatmap(
    corr_with_target.to_frame(),
    annot=True,
    cmap='coolwarm',
    center=0,
    fmt='.3f'
)

plt.title(f'Correlation with {target}')
plt.show()

# %%
df.hist(figsize=(15,8))
plt.subplots_adjust(hspace=2,wspace=1)
plt.show()

# %% [markdown]
# # Split Data

# %%
x = df.drop('Class', axis=1)
y = df['Class']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((226980, 30), (56746, 30), (226980,), (56746,))

# %% [markdown]
# # Data Preprocissing & Feature Engineering

# %%
def add_time_features(df):
    df = df.copy() 
    
    df['Hour'] = (df['Time'] % 86400) // 3600
    df['Minute'] = (df['Time'] % 3600) // 60

    df['Hour_sin'] = np.sin(2*np.pi*df['Hour']/24)
    df['Hour_cos'] = np.cos(2*np.pi*df['Hour']/24)

    df['Minute_sin'] = np.sin(2*np.pi*df['Minute']/60)
    df['Minute_cos'] = np.cos(2*np.pi*df['Minute']/60)

    df.drop(['Time','Hour', 'Minute'], axis=1, inplace=True)


    return df


x_train = add_time_features(x_train)
x_test = add_time_features(x_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train["Amount_scaled"] = scaler.fit_transform(x_train[["Amount"]])
x_test["Amount_scaled"] = scaler.transform(x_test[["Amount"]])

x_train.drop("Amount", axis=1, inplace=True)
x_test.drop("Amount", axis=1, inplace=True)

# %% [markdown]
# # Model Training and Evaluation

# %%
# Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

# Metrics
from sklearn.metrics import precision_recall_curve,f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,auc

# %%
def evaluate_model(model, X, y):
    y_pred = model.predict(X)
    y_prob = model.predict_proba(X)[:,1] if hasattr(model, 'predict_proba') else None

    metrics = {
        "accuracy": accuracy_score(y, y_pred),
        "precision": precision_score(y, y_pred),
        "recall": recall_score(y, y_pred),
        "f1": f1_score(y, y_pred),
        "confusion_matrix": confusion_matrix(y, y_pred),
        "y_pred": y_pred,
        "y_prob": y_prob
    }
    
    if y_prob is not None:
        fpr, tpr, _ = roc_curve(y, y_prob)
        metrics["roc_auc"] = auc(fpr, tpr)
    else:
        metrics["roc_auc"] = None
        
    return metrics

def plot_confusion_matrix(cm, model_name):
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal','Fraud'], yticklabels=['Normal','Fraud'])
    plt.title(f'Confusion Matrix - {model_name}', fontsize=14)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

def plot_roc_curve(y, y_prob, model_name):
    fpr, tpr, _ = roc_curve(y, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.figure(figsize=(6,5))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC AUC = {roc_auc:.4f}')
    plt.plot([0,1],[0,1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {model_name}')
    plt.legend()
    plt.show()

def plot_precision_recall_curve(y, y_prob, model_name):
    precision, recall, _ = precision_recall_curve(y, y_prob)
    pr_auc = auc(recall, precision)
    plt.figure(figsize=(6,5))
    plt.plot(recall, precision, color='blue', lw=2, label=f'PR AUC = {pr_auc:.4f}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve - {model_name}')
    plt.legend()
    plt.show()

# %%
results = {}

# %% [markdown]
# # Decision Tree

# %%
dt = DecisionTreeClassifier(random_state=42, max_depth=7)
dt.fit(x_train, y_train)

results = evaluate_model(dt, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Decision Tree")
plot_roc_curve(y_test, results["y_prob"], "Decision Tree")
plot_precision_recall_curve(y_test, results["y_prob"], "Decision Tree")
# Out:
# Accuracy: 0.9993303492757198
# Precision: 0.8904109589041096
# Recall: 0.6842105263157895
# F1: 0.7738095238095238
# ROC AUC: 0.8640796975758316

# %% [markdown]
# # Decision Tree (Class Weighted)

# %%
dt_Weighted = DecisionTreeClassifier(random_state=42, max_depth=7, class_weight='balanced')
dt_Weighted.fit(x_train, y_train)

results = evaluate_model(dt_Weighted, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Weighted Decision Tree")
plot_roc_curve(y_test, results["y_prob"], "Weighted Decision Tree")
plot_precision_recall_curve(y_test, results["y_prob"], "Weighted Decision Tree")
# Out:
# Accuracy: 0.9916822331089415
# Precision: 0.14366729678638943
# Recall: 0.8
# F1: 0.24358974358974358
# ROC AUC: 0.9031140807659828

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

results = evaluate_model(rf, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Random Forest")
plot_roc_curve(y_test, results["y_prob"], "Random Forest")
plot_precision_recall_curve(y_test, results["y_prob"], "Random Forest")
# Out:
# Accuracy: 0.9995418179254926
# Precision: 0.9726027397260274
# Recall: 0.7473684210526316
# F1: 0.8452380952380952
# ROC AUC: 0.929617538223416

# %% [markdown]
# # Random Forest (Class Weighted)

# %%
rf_Weighted = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf_Weighted.fit(x_train, y_train)

results = evaluate_model(rf_Weighted, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Weighted Random Forest")
plot_roc_curve(y_test, results["y_prob"], "Weighted Random Forest")
plot_precision_recall_curve(y_test, results["y_prob"], "Weighted Random Forest")
# Out:
# Accuracy: 0.9994889507630493
# Precision: 0.9852941176470589
# Recall: 0.7052631578947368
# F1: 0.8220858895705522
# ROC AUC: 0.9192469311174885

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
xgb.fit(x_train, y_train)
results = evaluate_model(xgb, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "XGBoost")
plot_roc_curve(y_test, results["y_prob"], "XGBoost")
plot_precision_recall_curve(y_test, results["y_prob"], "XGBoost")
# Out:
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:52:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.9993303492757198
# Precision: 0.8352941176470589
# Recall: 0.7473684210526316
# F1: 0.7888888888888889
# ROC AUC: 0.9171562911975355

# %%
xgb_Weighted = XGBClassifier(random_state=42, 
                             use_label_encoder=False, 
                             eval_metric='logloss', 
                             scale_pos_weight= (y_train == 0).sum() / (y_train == 1).sum())

xgb_Weighted.fit(x_train, y_train)
results = evaluate_model(xgb_Weighted, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Weighted XGBoost")
plot_roc_curve(y_test, results["y_prob"], "Weighted XGBoost")
plot_precision_recall_curve(y_test, results["y_prob"], "Weighted XGBoost")
# Out:
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:52:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.9994713283755683
# Precision: 0.9113924050632911
# Recall: 0.7578947368421053
# F1: 0.8275862068965517
# ROC AUC: 0.9781810884557247

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

x_train_resampled, y_train_resampled = smote.fit_resample(x_train, y_train)

print(y_train.value_counts())
print(y_train_resampled.value_counts())
# Out:
# Class
# 0    226602
# 1       378
# Name: count, dtype: int64
# Class
# 0    226602
# 1    226602
# Name: count, dtype: int64

# %%
rf_smote = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf_smote.fit(x_train_resampled, y_train_resampled)

results = evaluate_model(rf_smote, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Random Forest with SMOTE")
plot_roc_curve(y_test, results["y_prob"], "Random Forest with SMOTE")
plot_precision_recall_curve(y_test, results["y_prob"], "Random Forest with SMOTE")
# Out:
# Accuracy: 0.9994360836006062
# Precision: 0.8987341772151899
# Recall: 0.7473684210526316
# F1: 0.8160919540229885
# ROC AUC: 0.9538696302104576

# %% [markdown]
# # Final Model (Xgboost weighted)

# %%
xgb_Weighted = XGBClassifier(random_state=42, 
                             use_label_encoder=False, 
                             eval_metric='logloss', 
                             scale_pos_weight= (y_train == 0).sum() / (y_train == 1).sum())

xgb_Weighted.fit(x_train_resampled, y_train_resampled)
# Out:
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
fig = plt.figure(figsize=(10, 12))
feayure_importance = xgb_Weighted.feature_importances_
sorted_idx = np.argsort(feayure_importance)

plt.barh(range(len(sorted_idx)), feayure_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), x_train.columns[sorted_idx])
plt.title('Feature Importance - Weighted XGBoost')
plt.xlabel('Importance Score')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(xgb_Weighted, x_train_resampled, y_train_resampled, cv=5, scoring='roc_auc')

def display_scores(scores):
    print(f"Cross-Validation AUC Scores: {scores}")
    print(f"Mean AUC: {scores.mean():.4f}")
    print(f"Standard Deviation: {scores.std():.4f}")

display_scores(scores)
# Out:
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:57:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# ...

# %%
'''from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [100, 300, 500, 700, 900],
              'learning_rate': [0.01, 0.1, 0.2, 0.001, 0.05],
              'max_depth': [3, 5, 7, 10, 12]}

grid_search = GridSearchCV(
    estimator=xgb_Weighted,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    verbose=1
)

grid_search.fit(x_train_resampled, y_train_resampled)
best_param = grid_search.best_params_
print("Best Hyperparameters:", best_param)'''
# Out:
# 'from sklearn.model_selection import GridSearchCV\n\nparam_grid = {\'n_estimators\': [100, 300, 500, 700, 900],\n              \'learning_rate\': [0.01, 0.1, 0.2, 0.001, 0.05],\n              \'max_depth\': [3, 5, 7, 10, 12]}\n\ngrid_search = GridSearchCV(\n    estimator=xgb_Weighted,\n    param_grid=param_grid,\n    scoring=\'roc_auc\',\n    cv=5,\n    verbose=1\n)\n\ngrid_search.fit(x_train_resampled, y_train_resampled)\nbest_param = grid_search.best_params_\nprint("Best Hyperparameters:", best_param)'

# %%
xgb_Weighted = XGBClassifier(random_state=42,
                             max_depth= 5,
                             learning_rate= 0.2,
                             n_estimators= 900,
                             use_label_encoder=False, 
                             eval_metric='logloss', 
                             scale_pos_weight= (y_train == 0).sum() / (y_train == 1).sum())

xgb_Weighted.fit(x_train_resampled, y_train_resampled)
results = evaluate_model(xgb_Weighted, x_test, y_test)
print("Accuracy:", results["accuracy"])
print("Precision:", results["precision"])
print("Recall:", results["recall"])
print("F1:", results["f1"])
print("ROC AUC:", results["roc_auc"])
plot_confusion_matrix(results["confusion_matrix"], "Weighted XGBoost")
plot_roc_curve(y_test, results["y_prob"], "Weighted XGBoost")
plot_precision_recall_curve(y_test, results["y_prob"], "Weighted XGBoost")
# Out:
# c:\Users\osman\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [14:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.9993303492757198
# Precision: 0.8202247191011236
# Recall: 0.7684210526315789
# F1: 0.7934782608695652
# ROC AUC: 0.9593811230163634
